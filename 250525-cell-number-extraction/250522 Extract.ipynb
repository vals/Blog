# %%
import time

import pandas as pd
from firecrawl import FirecrawlApp
from pydantic import BaseModel, Field
from tqdm import tqdm

# %%
df = pd.read_csv('250522.100papers.tsv', sep = '\t')

# %%
app = FirecrawlApp()

# %%
class ExtractSchema(BaseModel):
    total_number_cells: int
    failure_reason: str
    url: str

# %%
doi = df['DOI'].sample().values[0]
url = 'https://doi.org/' + doi

# %%
url
# Out:
# 'https://doi.org/10.1242/dev.173476'

# %%
prompt = '''
The page is a paper where the authors performed single-cell RNA-sequencing.
Extract the total number of cells the authors report to have collected.
Store the number in the total_number_cells field.

If you cannot extract the number of cells, give a brief reason in the failure_reason field.

Report the URL that was called to extract in the url field.
'''

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
data
# Out:
# ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 5, 59, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1242/dev.173476', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None)

# %%
data.data
# Out:
# {'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.',
#  'total_number_cells': None}

# %%
urls = ['https://doi.org/' + u for u in ]

# %%
dois = df['DOI'].to_list()

# %%
datas = []

total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#  18%|█▊        | 18/100 [08:38<39:22, 28.81s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[43], line 8
#       6 doi = dois.pop()
#       7 url = 'https://doi.org/' + doi
# ----> 8 data = app.extract(
#       9     [url],
#      10     prompt = prompt,
#      11     schema = ExtractSchema.model_json_schema()
#      12 )
#      13 datas.append(data)
#      14 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#   5%|▍         | 4/81 [02:39<51:05, 39.82s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#   8%|▊         | 6/76 [03:18<38:33, 33.05s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#  22%|██▏       | 15/69 [06:41<24:05, 26.76s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[52], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#  32%|███▏      | 17/53 [07:37<16:08, 26.89s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#   3%|▎         | 1/35 [01:21<46:24, 81.88s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#  27%|██▋       | 9/33 [04:32<12:07, 30.30s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#  13%|█▎        | 3/23 [02:41<17:58, 53.94s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[64], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
#   5%|▌         | 1/19 [01:38<29:40, 98.94s/it]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1760, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1759     elif status_data['status'] in ['failed', 'cancelled']:
# -> 1760         raise Exception(f'Extract job {status_data["status"]}. Error: {status_data["error"]}')
#    1761 else:
#
# Exception: Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 6
#       4 doi = dois.pop()
#       5 url = 'https://doi.org/' + doi
# ----> 6 data = app.extract(
#       7     [url],
#       8     prompt = prompt,
#       9     schema = ExtractSchema.model_json_schema()
#      10 )
#      11 datas.append(data)
#      12 pbar.update(1)
#
# File ~/miniforge3/lib/python3.12/site-packages/firecrawl/firecrawl.py:1770, in FirecrawlApp.extract(self, urls, prompt, schema, system_prompt, allow_external_links, enable_web_search, show_sources, agent)
#    1768         self._handle_error(response, "extract")
#    1769 except Exception as e:
# -> 1770     raise ValueError(str(e), 500)
#    1772 return ExtractResponse(success=False, error="Internal server error.")
#
# ValueError: ('Extract job failed. Error: All provided URLs are invalid. Please check your input and try again.', 500)

# %%
data = app.extract(
    [url],
    prompt = prompt,
    schema = ExtractSchema.model_json_schema()
)

# %%
datas.append(data)

# %%
total = len(dois)
with tqdm(total = total) as pbar:
    while dois:
        doi = dois.pop()
        url = 'https://doi.org/' + doi
        data = app.extract(
            [url],
            prompt = prompt,
            schema = ExtractSchema.model_json_schema()
        )
        datas.append(data)
        pbar.update(1)
        time.sleep(10)
# Out:
# 100%|██████████| 17/17 [05:34<00:00, 19.70s/it]

# %%
datas
# Out:
# [ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 27, 14, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-024-08518-2', 'failure_reason': '', 'total_number_cells': 45766}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 27, 38, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.adn3949', 'failure_reason': '', 'total_number_cells': 21786931}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 28, 1, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41467-022-33140-z', 'failure_reason': '', 'total_number_cells': 500000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 28, 21, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.3390/ijms231810419', 'failure_reason': '', 'total_number_cells': 2667}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 28, 51, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.abp9444', 'failure_reason': '', 'total_number_cells': 33}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 29, 19, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.abl4896', 'failure_reason': '', 'total_number_cells': 483152}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 29, 41, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.immuni.2022.04.004', 'failure_reason': 'Total number of cells not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 30, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.ccell.2022.02.016', 'failure_reason': 'Total number of cells not specified in the content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 30, 35, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1002/hep4.1854', 'failure_reason': '', 'total_number_cells': 73295}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 30, 54, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.stemcr.2021.07.006', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 31, 18, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2021.04.005', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 31, 34, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.xcrm.2021.100219', 'failure_reason': '', 'total_number_cells': 3000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 31, 57, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41588-021-00801-6', 'failure_reason': '', 'total_number_cells': 1000000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 32, 28, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41593-020-00787-0', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 32, 57, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2021.01.010', 'failure_reason': '', 'total_number_cells': 138161}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 33, 23, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.aba7721', 'failure_reason': '', 'total_number_cells': 4000000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 33, 44, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2020.08.013', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 34, 11, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/sciadv.aba1972', 'failure_reason': '', 'total_number_cells': 114396}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 38, 37, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41467-020-17186-5', 'failure_reason': '', 'total_number_cells': 53586}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 39, 7, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.devcel.2020.06.009', 'failure_reason': 'The total number of cells collected by the authors was not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 39, 30, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41598-020-67730-y', 'failure_reason': 'The total number of cells collected is not explicitly stated in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 40, 5, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2020.06.001', 'failure_reason': 'Total number of cells not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 40, 25, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1073/pnas.2001896117', 'failure_reason': '', 'total_number_cells': 8758}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 47, 28, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-020-2316-7', 'failure_reason': '', 'total_number_cells': 1231}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 48, 1, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1073/pnas.2001250117', 'failure_reason': '', 'total_number_cells': 24023}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 48, 24, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41593-020-0624-8', 'failure_reason': '', 'total_number_cells': 7345}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 48, 44, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1101/2020.03.23.20039362', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 49, 10, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1084/jem.20190730', 'failure_reason': 'The total number of cells collected by the authors was not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 49, 33, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1093/ecco-jcc/jjaa054', 'failure_reason': '', 'total_number_cells': 5456}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 49, 49, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1080/2162402X.2020.1737369', 'failure_reason': 'Total number of cells not specified in the content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 55, 55, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.ebiom.2020.102686', 'failure_reason': '', 'total_number_cells': 62628}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 56, 30, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.stemcr.2020.01.007', 'failure_reason': '', 'total_number_cells': 12490}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 56, 49, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1002/glia.23777', 'failure_reason': '', 'total_number_cells': 5613}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 57, 13, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-019-1817-8', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 57, 36, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.aax6234', 'failure_reason': '', 'total_number_cells': 650000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 58, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1084/jem.20191130', 'failure_reason': '', 'total_number_cells': 14537}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 58, 23, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.15252/embj.2019101828', 'failure_reason': '', 'total_number_cells': 6894}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 58, 45, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1183/13993003.00646-2019', 'failure_reason': '', 'total_number_cells': 15288}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 59, 3, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.ajhg.2019.07.019', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 59, 24, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.15252/embj.2018100811', 'failure_reason': '', 'total_number_cells': 20009}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 11, 59, 47, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41591-019-0522-3', 'failure_reason': '', 'total_number_cells': 79046}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 0, 10, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.immuni.2019.06.017', 'failure_reason': '', 'total_number_cells': 2611}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 0, 34, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1161/CIRCRESAHA.118.314578', 'failure_reason': '', 'total_number_cells': 22362}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 0, 56, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41598-019-45842-4', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 1, 16, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.aax1184', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 1, 40, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2019.05.047', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 5, 51, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1002/mrd.23181', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 6, 56, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.immuni.2019.05.009', 'failure_reason': 'Total number of cells not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 7, 17, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.aas9536', 'failure_reason': '', 'total_number_cells': 1107}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 7, 40, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1242/dev.173716', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 7, 57, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1242/dev.173476', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 8, 16, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.immuni.2019.05.002', 'failure_reason': 'Total number of cells not specified in the content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 8, 39, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.3390/ijms20092316', 'failure_reason': '', 'total_number_cells': 1413}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 8, 59, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-019-1195-2', 'failure_reason': '', 'total_number_cells': 80660}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 9, 17, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-019-1154-y', 'failure_reason': '', 'total_number_cells': 8710}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 9, 36, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.7554/eLife.43882', 'failure_reason': '', 'total_number_cells': 30000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 10, 1, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1371/journal.pgen.1007810', 'failure_reason': '', 'total_number_cells': 2500}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 10, 24, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1242/dev.174177', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 10, 46, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cmet.2019.01.021', 'failure_reason': 'Total number of cells not specified in the content.', 'total_number_cells': 0}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 11, 7, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-019-0933-9', 'failure_reason': '', 'total_number_cells': 116312}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 11, 28, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-019-0969-x', 'failure_reason': '', 'total_number_cells': 2000000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 11, 50, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.devcel.2018.11.048', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 12, 12, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41590-018-0276-y', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 12, 33, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.devcel.2018.11.034', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 16, 15, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-018-0836-1', 'failure_reason': '', 'total_number_cells': 224}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 16, 45, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.celrep.2018.11.003', 'failure_reason': 'Total number of cells not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 20, 51, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41467-018-07540-z', 'failure_reason': '', 'total_number_cells': 11416}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 21, 13, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cels.2018.10.008', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 21, 33, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.celrep.2018.09.059', 'failure_reason': '', 'total_number_cells': 1873}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 21, 56, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41467-018-06423-7', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 22, 20, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1101/gad.317669.118', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 22, 41, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.7554/eLife.36865', 'failure_reason': '', 'total_number_cells': 3204}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 23, 5, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41467-018-06052-0', 'failure_reason': '', 'total_number_cells': 1189}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 23, 39, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1172/jci.insight.122211', 'failure_reason': '', 'total_number_cells': 3575}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 24, 1, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41586-018-0385-7', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 24, 22, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41422-018-0066-y', 'failure_reason': '', 'total_number_cells': 1471}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 30, 50, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1371/journal.pbio.2006387', 'failure_reason': '', 'total_number_cells': 3663}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 31, 51, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2018.05.004', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 32, 11, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.immuni.2018.04.015', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 32, 37, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.7554/eLife.33105', 'failure_reason': '', 'total_number_cells': 335}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 37, 48, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nature25999', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 38, 30, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1161/CIRCULATIONAHA.117.030742', 'failure_reason': '', 'total_number_cells': 935}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 42, 49, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/s41556-017-0013-z', 'failure_reason': '', 'total_number_cells': 20000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 43, 13, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nature24489', 'failure_reason': '', 'total_number_cells': 53193}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 43, 38, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nature24029', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 43, 55, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nature22370', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 44, 46, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/ncomms15081', 'failure_reason': '', 'total_number_cells': 515}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 45, 4, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.neuron.2017.03.017', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 45, 24, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nn.4495', 'failure_reason': '', 'total_number_cells': 20921}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 45, 40, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/NMICROBIOL.2016.206', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 45, 55, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cels.2016.08.011', 'failure_reason': '', 'total_number_cells': 12000}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 46, 11, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cmet.2016.08.018', 'failure_reason': '', 'total_number_cells': 1492}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 46, 29, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2016.08.052', 'failure_reason': 'Total number of cells not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 46, 44, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2016.07.054', 'failure_reason': '', 'total_number_cells': 27499}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 47, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.2337/db16-0405', 'failure_reason': '', 'total_number_cells': 635}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 47, 16, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1126/science.aaf1204', 'failure_reason': '', 'total_number_cells': 3227}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 47, 31, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nature18323', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 47, 48, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1186/s13059-016-0957-5', 'failure_reason': '', 'total_number_cells': 78}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 48, 6, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1016/j.cell.2015.05.002', 'failure_reason': 'The total number of cells collected is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None),
#  ExtractResponse(id=None, status='completed', expiresAt=datetime.datetime(2025, 5, 23, 12, 48, 28, tzinfo=TzInfo(UTC)), success=True, data={'url': 'https://doi.org/10.1038/nmeth.2772', 'failure_reason': 'The total number of cells collected by the authors is not specified in the provided content.', 'total_number_cells': None}, error=None, warning=None, sources=None)]

# %%
e_data = [d.data for d in datas]

# %%
df_e = pd.DataFrame(e_data)
df_e['total_number_cells'] = df_e['total_number_cells'].astype('Int64')
df_e
# Out:
#                                            url  \
# 0   https://doi.org/10.1038/s41586-024-08518-2
# 1      https://doi.org/10.1126/science.adn3949
# 2   https://doi.org/10.1038/s41467-022-33140-z
# 3        https://doi.org/10.3390/ijms231810419
# 4      https://doi.org/10.1126/science.abp9444
# ..                                         ...
# 95     https://doi.org/10.1126/science.aaf1204
# 96         https://doi.org/10.1038/nature18323
# 97   https://doi.org/10.1186/s13059-016-0957-5
# 98  https://doi.org/10.1016/j.cell.2015.05.002
# 99          https://doi.org/10.1038/nmeth.2772
#
#                                        failure_reason  total_number_cells
# 0                                                                   45766
# 1                                                                21786931
# 2                                                                  500000
# 3                                                                    2667
# 4                                                                      33
# ..                                                ...                 ...
# 95                                                                   3227
# 96  The total number of cells collected by the aut...                <NA>
# 97                                                                     78
# 98  The total number of cells collected is not spe...                <NA>
# 99  The total number of cells collected by the aut...                <NA>
#
# [100 rows x 3 columns]

# %%
df_e['failure_reason'].value_counts()
# Out:
# failure_reason
#                                                                                                  57
# The total number of cells collected by the authors is not specified in the provided content.     17
# The total number of cells collected is not specified in the provided content.                    14
# Total number of cells not specified in the provided content.                                      5
# Total number of cells not specified in the content.                                               4
# The total number of cells collected by the authors was not specified in the provided content.     2
# The total number of cells collected is not explicitly stated in the provided content.             1
# Name: count, dtype: int64

# %%
df_e.to_csv('250522.firecrawl.results.csv', index = False)

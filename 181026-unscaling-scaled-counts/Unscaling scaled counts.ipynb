# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
ls
# Out:
# GEO_parsed.csv
# GSE114374_Human_HC_expression_matrix.txt.gz
# GSE114374_Human_UC_expression_matrix.txt.gz
# GSE95435_P150057_full_gene_count_table.txt.gz
# GSE95446_P150409_full_gene_count_table.txt.gz
# GSE95450_P160099_full_gene_count_table.txt.gz
# Make Anndata file for C1 data.ipynb
# Make anndata for 10X data.ipynb
# Sample info.gsheet
# gsms.csv
# kinchen_c1_data.h5ad

# %%
df = pd.read_csv('GSE114374_Human_HC_expression_matrix.txt.gz', sep='\t').T

# %%
df.iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
plt.scatter(df.mean(0), df.var(0), marker='.', c='k', label='Genes');
plt.xlabel('Mean')
plt.ylabel('Variance')
plt.legend(scatterpoints=3);
plt.savefig('1.png', dpi=150)

# %%
np.power(2, df).iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           1.0      1.0    1.0           1.0
# AAACCTGCACAACTGT-S66           1.0      1.0    1.0           1.0
# AAACCTGCACCCTATC-S66           1.0      1.0    1.0           1.0
# AAACCTGCAGGCTCAC-S66           1.0      1.0    1.0           1.0
# AAACCTGCAGTCTTCC-S66           1.0      1.0    1.0           1.0
# AAACCTGGTCATACTG-S66           1.0      1.0    1.0           1.0
# AAACCTGGTGCTGTAT-S66           1.0      1.0    1.0           1.0
# AAACCTGGTGTAATGA-S66           1.0      1.0    1.0           1.0
# AAACCTGTCAAACCGT-S66           1.0      1.0    1.0           1.0
# AAACGGGAGACTGTAA-S66           1.0      1.0    1.0           1.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           1.0            1.0           1.0         1.0
# AAACCTGCACAACTGT-S66           1.0            1.0           1.0         1.0
# ...

# %%
(np.power(2, df) - 1).iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
(np.power(2, df) - 1).sum(1).head()
# Out:
# AAACCTGCAAGGACTG-S66    4104.042482
# AAACCTGCACAACTGT-S66    3778.012827
# AAACCTGCACCCTATC-S66    3864.976063
# AAACCTGCAGGCTCAC-S66    3680.012588
# AAACCTGCAGTCTTCC-S66    3964.072334
# dtype: float64

# %%
(np.power(10, df) - 1).iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
(np.power(10, df) - 1).sum(1).head()
# Out:
# AAACCTGCAAGGACTG-S66    1.732808e+06
# AAACCTGCACAACTGT-S66    5.272909e+06
# AAACCTGCACCCTATC-S66    1.300905e+06
# AAACCTGCAGGCTCAC-S66    4.168346e+06
# AAACCTGCAGTCTTCC-S66    4.297202e+06
# dtype: float64

# %%
(np.power(np.e, df) - 1).iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
(np.exp(df) - 1).sum(1).head()
# Out:
# AAACCTGCAAGGACTG-S66    10000.0
# AAACCTGCACAACTGT-S66    10000.0
# AAACCTGCACCCTATC-S66    10000.0
# AAACCTGCAGGCTCAC-S66    10000.0
# AAACCTGCAGTCTTCC-S66    10000.0
# dtype: float64

# %%
counts = np.exp(df) - 1

# %%
counts.iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
counts = np.expm1(df)

# %%
counts.sum(1).head()
# Out:
# AAACCTGCAAGGACTG-S66     9630.0
# AAACCTGCACAACTGT-S66    10169.0
# AAACCTGCACCCTATC-S66     9834.0
# AAACCTGCAGGCTCAC-S66    10390.0
# AAACCTGCAGTCTTCC-S66    10455.0
# dtype: float64

# %%
np.expm1(df).sum(1).head()
# Out:
# AAACCTGCAAGGACTG-S66    10000.0
# AAACCTGCACAACTGT-S66    10000.0
# AAACCTGCACCCTATC-S66    10000.0
# AAACCTGCAGGCTCAC-S66    10000.0
# AAACCTGCAGTCTTCC-S66    10000.0
# dtype: float64

# %%
cptt = np.expm1(df)

# %%
plt.loglog()
plt.scatter(cptt.mean(0), cptt.var(0), c='k', marker='.', label='Genes')
plt.plot([1e-4, 1e3], [1e-4, 1e3], c='r')
plt.xlim(1e-5);
plt.ylim(1e-6);
plt.xlabel('Mean')
plt.ylabel('Variance')
plt.title('Counts per 10k')
plt.legend(scatterpoints=3);
plt.savefig('2.png', dpi=150)

# %%
c = cptt.iloc[1990]
c.value_counts().head()
# Out:
# 0.000000     32427
# 3.773585       892
# 7.547170       190
# 11.320755       73
# 15.094340       28
# Name: TAGTGGTTCGGTGTTA-S66, dtype: int64

# %%
c = cptt.iloc[17]
c.value_counts().head()
# Out:
# 0.000000     32571
# 4.897160       829
# 9.794319       144
# 14.691479       53
# 19.588639       35
# Name: AAAGATGGTCATCCCT-S66, dtype: int64

# %%
c = cptt.iloc[256]
c.value_counts().head()
# Out:
# 0.000000    31936
# 1.639613     1154
# 3.279226      266
# 4.918839       66
# 6.558452       52
# Name: ACTATCTGTCTTGCGG-S66, dtype: int64

# %%
for c_idx in [23, 654, 43, 543, 2644]:
    N = 10
    c = cptt.iloc[c_idx]
    y = c.value_counts().sort_index().head(N).index
    x = np.arange(0, N)
    plt.scatter(x, y, label=f'Cell {c_idx}');
    

plt.legend()
plt.xlabel('Rank in cell histogram')
plt.ylabel('Scaled count');
plt.xticks(x);
plt.savefig('3.png', dpi=150)

# %%
np.linalg.lstsq(y[:, None], x[:, None], rcond=-1)[0]
# Out:
# array([[0.3517]])

# %%
for c_idx in [23, 654, 43, 543, 2644]:
    N = 10
    c = df.iloc[c_idx]
    y = c.value_counts().sort_index().head(N).index
    x = np.arange(0, N)
    plt.scatter(x, y);
    
plt.xlabel('Rank')
plt.ylabel('log Scaled count + 1');
plt.xticks(x);

# %%
for c_idx in [23, 654, 43, 543, 2644]:
    N = 10
    c = df.iloc[c_idx]
    c = np.power(10, c) - 1
    y = c.value_counts().sort_index().head(N).index
    x = np.arange(0, N)
    plt.scatter(x, y);
    
plt.xlabel('Rank')
plt.ylabel('log Scaled count + 1');
plt.xticks(x);

# %%
def get_scaling_factor(r):
    N = 10
    h = r.value_counts().sort_index()
    N_ = np.minimum(h.shape[0], N)
    y = h.head(N_).index
    x = np.arange(N_)
    s = np.linalg.lstsq(y[:, None], x[:, None], rcond=-1)[0][0, 0]
    
    return s

# %%
scaling_factors = cptt.apply(get_scaling_factor, axis=1)

# %%
scaling_factors.head()
# Out:
# AAACCTGCAAGGACTG-S66    0.8341
# AAACCTGCACAACTGT-S66    0.2597
# AAACCTGCACCCTATC-S66    0.4415
# AAACCTGCAGGCTCAC-S66    0.3928
# AAACCTGCAGTCTTCC-S66    0.5708
# dtype: float64

# %%
counts = (cptt.T * scaling_factors).T
counts.iloc[:10, :10]
# Out:
#                       RP11-34P13.3  FAM138A  OR4F5  RP11-34P13.7  \
# AAACCTGCAAGGACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGCACAACTGT-S66           0.0      0.0    0.0           0.0
# AAACCTGCACCCTATC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGGCTCAC-S66           0.0      0.0    0.0           0.0
# AAACCTGCAGTCTTCC-S66           0.0      0.0    0.0           0.0
# AAACCTGGTCATACTG-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGCTGTAT-S66           0.0      0.0    0.0           0.0
# AAACCTGGTGTAATGA-S66           0.0      0.0    0.0           0.0
# AAACCTGTCAAACCGT-S66           0.0      0.0    0.0           0.0
# AAACGGGAGACTGTAA-S66           0.0      0.0    0.0           0.0
#
#                       RP11-34P13.8  RP11-34P13.14  RP11-34P13.9  FO538757.3  \
# AAACCTGCAAGGACTG-S66           0.0            0.0           0.0         0.0
# AAACCTGCACAACTGT-S66           0.0            0.0           0.0         0.0
# ...

# %%
plt.loglog()
plt.scatter(counts.sum(1), (counts > 0).sum(1), c='k', label='Cells');
plt.xlabel('Total count')
plt.ylabel('Genes detected');
plt.title('Recovered counts')
plt.legend(scatterpoints=3);
plt.savefig('4.png', dpi=150)

# %%
plt.loglog()
plt.scatter(counts.mean(0), counts.var(0), c='k', marker='.', label='Genes')
plt.plot([1e-4, 1e3], [1e-4, 1e3], c='r')
plt.xlim(1e-5);
plt.ylim(1e-6);
plt.xlabel('Mean')
plt.ylabel('Variance')
plt.title('Recovered counts')
plt.legend(scatterpoints=3);
plt.savefig('5.png', dpi=150)
